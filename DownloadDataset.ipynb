# %% [markdown]
# #Data Downloading and converting to appropriate format

# %%
# !pip list
# Out:
# Package                      Version     Editable project location
# ---------------------------- ----------- ------------------------------------------------------------------------------------------------------
# absl-py                      1.0.0
# aiofiles                     0.8.0
# anyio                        3.6.1
# apache-beam                  2.39.0
# argcomplete                  2.0.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# avro-python3                 1.10.2
# awscli                       1.24.10
# Babel                        2.10.1
# backcall                     0.2.0
# backports.cached-property    1.0.1
# backports.zoneinfo           0.2.1
# beautifulsoup4               4.11.1
# bleach                       5.0.0
# boto3                        1.23.10
# botocore                     1.26.10
# ...

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git

# %%
# !python OIDv4_ToolKit/main.py downloader -y --classes Fish Goldfish --type_csv validation --multiclasses 1 --image_IsGroupOf 0

# %%
# !git clone https://github.com/AtriSaxena/OIDv4_to_VOC.git

# %%
# !python OIDv4_to_VOC/OIDv4_to_VOC.py --sourcepath "" --dest_path ""
